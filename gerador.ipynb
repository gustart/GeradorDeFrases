# %%
# !pip install transformers

# %%
import transformers
from transformers import pipeline

# %%
gerador = pipeline("text-generation", model="pierreguillou/gpt2-small-portuguese")
# Out:
# Downloading config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/487M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/92.0 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/830k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/496k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]

# %%
texto = "Em sentido estrito, ciência refere-se ao sistema de adquirir conhecimento baseado no método científico."
resultado = gerador(texto, max_length=60, do_sample=True)
print(resultado)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Em sentido estrito, ciência refere-se ao sistema de adquirir conhecimento baseado no método científico. Esta é um princípio que permite uma definição formal de conhecimento científico.\n\nA ciência é o estudo da natureza das coisas e das suas propriedades, que normalmente envolve um estudo exaustivo em busca do que significa a'}]
